# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Wetter_Juni_maxTemp.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466 entries, 0 to 465
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FID               466 non-null    object
#  1   SDO_GEOM          466 non-null    object
#  2   SDO_TYPE          466 non-null    object
#  3   SDO_GUID          466 non-null    int64
#  4   SDO_CODE          466 non-null    int64
#  5   SDO_NAME          466 non-null    object
#  6   ZEITSTEMPEL       466 non-null    object
#  7   ZEITINTERVALL     466 non-null    object
#  8   WERT              466 non-null    float64
#  9   EINHEIT           466 non-null    object
#  10  QUALITAET_BYTE    466 non-null    int64
#  11  QUALITAET_NIVEAU  466 non-null    int64
#  12  BEOBACHTER_GUID   466 non-null    int64
#  13  STATION_ID        466 non-null    int64
#  14  STATION_NAME      466 non-null    object
#  15  GEOM              466 non-null    object
# ...

# %%
df.tail()
# Out:
#                                                    FID  \
# 461  OBS_DEU_P1M_T2M_X.2509331556728974994701000018...
# 462  OBS_DEU_P1M_T2M_X.2509331556665905334691704814...
# 463  OBS_DEU_P1M_T2M_X.2509331556680279462686922755...
# 464  OBS_DEU_P1M_T2M_X.2509331556662085129101722586...
# 465  OBS_DEU_P1M_T2M_X.2509331556714492063382016761...
#
#                         SDO_GEOM SDO_TYPE      SDO_GUID  SDO_CODE  \
# 461  POINT (10.584889 47.876124)  STATION  812301001939     15555
# 462  POINT (11.266503 50.907431)  STATION  812301001980       379
# 463  POINT (10.260783 48.487813)  STATION  812301005288      1886
# 464  POINT (12.851826 52.943711)  STATION  812301005418        96
# 465    POINT (8.10572 47.700344)  STATION  812301011155      5688
#
#                    SDO_NAME ZEITSTEMPEL ZEITINTERVALL   WERT EINHEIT  \
# 461   Kaufbeuren-Oberbeuren  2020-06-01           P1M  18.33      °C
# 462  Berka, Bad (Flugplatz)  2020-06-01           P1M  21.67      °C
# ...

# %%
df['ZEITSTEMPEL'] = pd.to_datetime(df['ZEITSTEMPEL'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466 entries, 0 to 465
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FID               466 non-null    object
#  1   SDO_GEOM          466 non-null    object
#  2   SDO_TYPE          466 non-null    object
#  3   SDO_GUID          466 non-null    int64
#  4   SDO_CODE          466 non-null    int64
#  5   SDO_NAME          466 non-null    object
#  6   ZEITSTEMPEL       466 non-null    datetime64[ns]
#  7   ZEITINTERVALL     466 non-null    object
#  8   WERT              466 non-null    float64
#  9   EINHEIT           466 non-null    object
#  10  QUALITAET_BYTE    466 non-null    int64
#  11  QUALITAET_NIVEAU  466 non-null    int64
#  12  BEOBACHTER_GUID   466 non-null    int64
#  13  STATION_ID        466 non-null    int64
#  14  STATION_NAME      466 non-null    object
#  15  GEOM              466 non-null    object
# ...

# %%
df.groupby('ZEITSTEMPEL')['WERT'].mean()
# Out:
# ZEITSTEMPEL
# 2020-06-01    22.021373
# Name: WERT, dtype: float64
