# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import pymongo
from datetime import datetime
import processes as ps #see processes.py


collection = "muenchen_20200404_shortLatLon"

myclient = pymongo.MongoClient('mongodb://admin:password@127.0.0.1:27017')
mydb = myclient["bikedate"]
mycol = mydb[collection]

abfrageErgebnis = mycol.find()
listFromAbfrageErgebnis = list(abfrageErgebnis)
df = pd.DataFrame(listFromAbfrageErgebnis)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
routes = ps.transform(df) #Reads the Dataframe, calculates the Routes on Map and returns a Dictionary with Routeinfos
print(routes[0])
# Out:
# {'bikeid': '8F3014B230A6CDD51DE24DFFB284EFABDD0ECBF0', 'date': '2020-04-04', 'starttime': Timestamp('2020-04-04 01:12:58.825000'), 'endtime': Timestamp('2020-04-04 01:18:17.308000'), 'startlon': 11.576, 'startlat': 48.136, 'endlon': 11.576, 'endlat': 48.137, 'route': [2320852071, 21474416, 253932875, 2545258011, 4348232950, 4348232955, 1955018, 1955016, 2586658049, 2330735001], 'streetlist': ['Petersplatz', 'Viktualienmarkt', 'Sparkassenstraße', 'Burgstraße', 'Altenhofstraße', 'Landschaftstraße']}

# %%
ps.pltfromdoc(routes) #Reads the Dictionary and plots the Routemap and saves it as png into the folder images

# %%
ps.heatfromdoc(routes) #Reads the Dictionary, calculates the Timeseries and plots the Heatmap and saves it to index.html
#see index.html

# %%
ps.pltStreetCount(routes) #plots Streetcount
