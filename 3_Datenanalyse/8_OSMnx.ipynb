# %%
# import modules
import osmnx as ox

# specify city
place_name = "Eimsbüttel, Hamburg, Germany"
# "Munich, Bavaria, Germany"
# "Berlin, 10117, Germany"

# fetch OSM street network from the location
graph = ox.graph_from_place(place_name, network_type='bike')

# %%
# check the data type of the graph
type(graph)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
# plot the streets
ox.plot_graph(graph)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
area = ox.geocode_to_gdf(place_name)

# %%
#plot
area.plot()
# Out:
# <AxesSubplot:>

# %%
# retrieve subway stations
tags = {'amenity': True, 'subway':'subway_station'}
subway = ox.geometries_from_place(place_name, tags)

# %%
# how many stations
len(subway)
# Out:
# 1134

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,8))

# plot subway area and stations
area.plot(ax=ax, facecolor= "black")
subway.plot(ax=ax, facecolor= "red", alpha = 0.7)
# Out:
# <AxesSubplot:>

# %%
# network analysis

import networkx as nx
import geopandas as gpd
import matplotlib as plt
import pandas as pd

# %%
# use graph from above for bikes

ox.plot.plot_graph(graph)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
# retrieve only edges from the graph
edges = ox.graph_to_gdfs(graph, nodes=False, edges=True)

# %%
#check columns
edges.columns
# Out:
# Index(['osmid', 'name', 'highway', 'width', 'oneway', 'length', 'maxspeed',
#        'geometry', 'lanes', 'ref', 'service', 'tunnel', 'bridge', 'access',
#        'junction'],
#       dtype='object')

# %%
#check crs
edges.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# project graph
graph_proj = ox.project_graph(graph)

# %%
ox.plot_graph(graph_proj)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
import networkx as nx
import osmnx as ox

place_name = "Munich, Bavaria, Germany"
ox.config(use_cache=True, log_console=True)

G = ox.graph_from_place(place_name, network_type='bike')
